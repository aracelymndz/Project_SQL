# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "nyse-fundamentals.csv"
nyse_fund = pd.read_csv(csv_file)


nyse_fund.head()
# Out:
#    Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0           0           AAL    2012-12-31      3.068000e+09
# 1           1           AAL    2013-12-31      4.975000e+09
# 2           2           AAL    2014-12-31      4.668000e+09
# 3           3           AAL    2015-12-31      5.102000e+09
# 4           4           AAP    2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0         -1.888000e+09     4.695000e+09        53.0  ...
# 1         -3.114000e+09     1.059200e+10        75.0  ...
# ...

# %%
# new_list = nyse_fund.drop_duplicates(['Ticker Symbol'], keep='last')
new_list_tickers = nyse_fund.rename(columns={'Unnamed: 0': 'Id', 'Ticker Symbol': 'Ticker_Symbol', 'Period Ending': 'Period_Ending', 
                                            'Sales, General and Admin.': 'Sales', 'Total Revenue': 'Total_Revenue', 
                                            'Net Income': 'Net_Income', 'Cost of Revenue': 'Cost_Revenue', 
                                            'Accounts Payable': 'Accounts_Payable', 
                                            'Accounts Receivable': 'Accounts_Receivable'})          
new_list_tickers.head()
# Out:
#    Id Ticker_Symbol Period_Ending  Accounts_Payable  Accounts_Receivable  \
# 0   0           AAL    2012-12-31      3.068000e+09         -222000000.0
# 1   1           AAL    2013-12-31      4.975000e+09          -93000000.0
# 2   2           AAL    2014-12-31      4.668000e+09         -160000000.0
# 3   3           AAL    2015-12-31      5.102000e+09          352000000.0
# 4   4           AAP    2012-12-29      2.409453e+09          -89482000.0
#
#    Add'l income/expense items  After Tax ROE  Capital Expenditures  \
# 0               -1.961000e+09           23.0         -1.888000e+09
# 1               -2.723000e+09           67.0         -3.114000e+09
# 2               -1.500000e+08          143.0         -5.311000e+09
# 3               -7.080000e+08          135.0         -6.151000e+09
# 4                6.000000e+05           32.0         -2.711820e+08
#
#    Capital Surplus  Cash Ratio  ...  Total Current Assets  \
# 0     4.695000e+09        53.0  ...          7.072000e+09
# ...

# %%
new_fundamentals = new_list_tickers[['Ticker_Symbol','Period_Ending', 'Sales', 'Total_Revenue', 'Net_Income', 'Inventory', 'Cost_Revenue', 'Accounts_Payable', 'Accounts_Receivable']].copy()
new_fundamentals.head()
# Out:
#   Ticker_Symbol Period_Ending         Sales  Total_Revenue    Net_Income  \
# 0           AAL    2012-12-31  1.297700e+10   2.485500e+10 -1.876000e+09
# 1           AAL    2013-12-31  1.291300e+10   2.674300e+10 -1.834000e+09
# 2           AAL    2014-12-31  2.068600e+10   4.265000e+10  2.882000e+09
# 3           AAL    2015-12-31  2.127500e+10   4.099000e+10  7.610000e+09
# 4           AAP    2012-12-29  2.440721e+09   6.205003e+09  3.876700e+08
#
#       Inventory  Cost_Revenue  Accounts_Payable  Accounts_Receivable
# 0  5.800000e+08  1.049900e+10      3.068000e+09         -222000000.0
# 1  1.012000e+09  1.101900e+10      4.975000e+09          -93000000.0
# 2  1.004000e+09  1.562000e+10      4.668000e+09         -160000000.0
# 3  8.630000e+08  1.109600e+10      5.102000e+09          352000000.0
# 4  2.308609e+09  3.106967e+09      2.409453e+09          -89482000.0

# %%
csv_file = "nyse-securities.csv"
customer_data_df = pd.read_csv(csv_file)

customer_data_df
# Out:
#     Ticker symbol                       Security SEC filings  \
# 0             MMM                     3M Company     reports
# 1             ABT            Abbott Laboratories     reports
# 2            ABBV                         AbbVie     reports
# 3             ACN                  Accenture plc     reports
# 4            ATVI            Activision Blizzard     reports
# 5             AYI              Acuity Brands Inc     reports
# 6            ADBE              Adobe Systems Inc     reports
# 7             AAP             Advance Auto Parts     reports
# 8             AES                       AES Corp     reports
# 9             AET                      Aetna Inc     reports
# 10            AMG  Affiliated Managers Group Inc     reports
# 11            AFL                      AFLAC Inc     reports
# 12              A       Agilent Technologies Inc     reports
# 13            APD   Air Products & Chemicals Inc     reports
# ...

# %%
# new_costumer_data = customer_data_df.drop_duplicates()

# %%
new_customer_data_df = customer_data_df[['Ticker symbol','Security','GICS Sector', 'GICS Sub Industry']].copy()
new_customer_data_df.head()
# Out:
#   Ticker symbol             Security             GICS Sector  \
# 0           MMM           3M Company             Industrials
# 1           ABT  Abbott Laboratories             Health Care
# 2          ABBV               AbbVie             Health Care
# 3           ACN        Accenture plc  Information Technology
# 4          ATVI  Activision Blizzard  Information Technology
#
#                 GICS Sub Industry
# 0        Industrial Conglomerates
# 1           Health Care Equipment
# 2                 Pharmaceuticals
# 3  IT Consulting & Other Services
# 4     Home Entertainment Software

# %%
df = pd.DataFrame(new_customer_data_df)

df.head()
# Out:
#   Ticker symbol             Security             GICS Sector  \
# 0           MMM           3M Company             Industrials
# 1           ABT  Abbott Laboratories             Health Care
# 2          ABBV               AbbVie             Health Care
# 3           ACN        Accenture plc  Information Technology
# 4          ATVI  Activision Blizzard  Information Technology
#
#                 GICS Sub Industry
# 0        Industrial Conglomerates
# 1           Health Care Equipment
# 2                 Pharmaceuticals
# 3  IT Consulting & Other Services
# 4     Home Entertainment Software

# %%
df_1 =  pd.DataFrame(new_fundamentals)

df_1['Year'] = pd.DatetimeIndex(df_1['Period_Ending']).year

df_1

remove_year = del
# Out:
#      Ticker_Symbol Period_Ending         Sales  Total_Revenue    Net_Income  \
# 0              AAL    2012-12-31  1.297700e+10   2.485500e+10 -1.876000e+09
# 1              AAL    2013-12-31  1.291300e+10   2.674300e+10 -1.834000e+09
# 2              AAL    2014-12-31  2.068600e+10   4.265000e+10  2.882000e+09
# 3              AAL    2015-12-31  2.127500e+10   4.099000e+10  7.610000e+09
# 4              AAP    2012-12-29  2.440721e+09   6.205003e+09  3.876700e+08
# 5              AAP    2013-12-28  2.591828e+09   6.493814e+09  3.917580e+08
# 6              AAP    2015-01-03  3.601903e+09   9.843861e+09  4.938250e+08
# 7              AAP    2016-01-02  3.596992e+09   9.737018e+09  4.733980e+08
# 8             AAPL    2013-09-28  1.083000e+10   1.709100e+11  3.703700e+10
# 9             AAPL    2014-09-27  1.199300e+10   1.827950e+11  3.951000e+10
# 10            AAPL    2015-09-26  1.432900e+10   2.337150e+11  5.339400e+10
# ...
